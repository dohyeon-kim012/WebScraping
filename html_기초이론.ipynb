# %% [markdown]
# <a href="https://colab.research.google.com/github/dohyeon-kim012/WebScraping/blob/main/html_%EA%B8%B0%EC%B4%88%EC%9D%B4%EB%A1%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. HTML
#   * Hyper Text Markup Language의 약자
#     * Hyper Text : 페이지 이동이 가능한...
#     * Markup : 구간이 있는..
#     * Language : 언어
#
#   * Markup
#     * 나는 어제 사과를 먹었다. -> 사람은 이해가 가능, 컴퓨터는 이해가 어렵다.
#     * Markup 예시
#     ```xml
#       <누가>나</누가>
#       <언제>어제</언제>
#       <무엇을>사과</무엇을>
#       <어떻게>먹다</어떻게>
#     ```
#     --> <누가> , </누가> : `Tag` / 나 : `Text`
#   * HTML은 웹에 보이는 화면인 웹 페이지를 구성하는 Markup 언어
#   * 웹 페이지를 구성하는 언어
#     * HTML : 마크업을 이용해 화면의 레이아웃(구조)와 텍스트, 엘리먼트
#         - 엘리먼트 ( 요소 ) : 버튼, 검색창 등 화면에 그려지는 모든 것들 / html 태그로 만들어지는 결과물
#     * CSS : 화면의 색상, 크기, 애니메이션 등의 스타일 담당 / ( HTML에 화장 시켜주기 )
#     * Javascript : 사용자와 웹 페이지의 인터렉션을 담당 ( 버튼을 클릭 했을 때~, 마우스가 올라왔을 때 ~ )

# %% [markdown]
# ## 1-1 HTML 구성 요소
# * Browser
#   - 주소창이나 북마크 등, 브라우저의 정보창
# * Document
#   * ( 눈에 보고 있는 ) 페이지 전체
#   - 가지고 올 "정보" 를 포함함
# * Element
#   * 계층적 구조로 이루어져 있으며 모여서 Document를 이룸
#     * 부모 자식 관계가 있다
#     * 레이아웃을 구성 하다보면 엘리먼트 안에 엘리먼트가 포함되는 경우가 있다
#         --> **DOM** ( Document object Model )
#     * ```html
#         <div>
#             <p> 안녕하세요! </p>
#         </div>
#
#         * <div>는 <p>의 부모 이다.
#         * <p>는 <div>의 자식 이다.
#       ```
#       '부모'는 1개, '자식'은 여러 개일 수 있다
#       같은 부모 아래의 자식 끼리는 '형제' 관계가 된다 ( Sibling )
#       자식의 자식은 '손주'이고, 자식과 손주를 모두 합하면 부모 엘리먼트의 '자손'들이 된다
#
#   * 시작 태그와 끝 태그로 구성 되어 있다
#     * ```html
#       <div> Hello </div>
#       <div> : 시작 태그
#       </div> : 끝 태그
#     ```
# * Tag
#   * 태그와 태그 사이에는 **문자열 데이터**만 가질 수 있다
#   * 태그의 이름에 따라서 태그의 모양과 기능(목적)이 달라진다
#   - 태그가 만들어질 때마다 엘리먼트도 더 만들어진다
#   ( -> 태그를 활용하여 엘리먼트를 만든다 )
# * Attribute
#   * 시작 태그 안에 포함되는 **속성**값
#      - 속성값 : ex)
#         ```
#         < 사람 이름 = 'A' >
#         < 사람 이름 = 'B' >
#         ```
#         사람 은 '이름' 이라는 속성을 가진다

# %% [markdown]
# `%%html` : 코랩에서 html을 쓰기 위한 매직 커맨드
# `<div>` : Tag
# `<class>` : attribute name ( 속성명 )
# `"wrapper"` : 속성값
# --> `div.wrapper` 로 표현
#
# `HTML1` : Text
#
# ![image.png](data:image/png;base64,...)

# %%
# %%html  # html을 쓰기 위한 매직 커맨드
# <div class="wrapper">
#   <button id="btn1" class="bt no1">HTML1</button>
#   <button id="btn2" class="bt no2" style="color:red;">HTML2</button>
# </div>
# Out:
# <div class="wrapper">
#   <button id="btn1" class="bt no1">HTML1</button>
#   <button id="btn2" class="bt no2" style="color:red;">HTML2</button>
# </div>

# %% [markdown]
# ## 1-2 속성값
# * id
#   * 웹 페이지에서 유일한 속성값 - **중복이 되면 안된다**
# * class
#   - 중복 가능 ( 띄어쓰기 포함 )
#   * 웹 페이지 내에서 여러 가지의 값 사용 가능
#   * 하나의 엘리먼트에 여러 가지 값 사용 가능
#   * `css`로 꾸미기 위한 용도

# %% [markdown]
# ## 1-3 태그의 종류

# %% [markdown]
# **Header**
# * 제목을 나타낼 때 사용
# * <h`n`>제목명</h`n`>
#   * `n`은 1 ~ 6
#   * `n`이 작을 수록 글씨가 커져요

# %%
# %%html
# <h1>Title 1</h1>
# <h2>Title 2</h2>
# <h3>Title 3</h3>
# <h4>Title 4</h4>
# <h5>Title 5</h5>
# <h6>Title 6</h6>
# Out:
# <h1>Title 1</h1>
# <h2>Title 2</h2>
# <h3>Title 3</h3>
# <h4>Title 4</h4>
# <h5>Title 5</h5>
# <h6>Title 6</h6>

# %% [markdown]
# **Paragraph**
#   * 문단을 나타낼 때 사용
#   * `<p> 내용 </p>`

# %%
# %%html
# <p>파이썬을 이용한 html 공부하기 입니다.</p>
# <p>빨리 html 크롤링을 하고 싶어요!</p>
# Out:
# <p>파이썬을 이용한 html 공부하기 입니다.</p>
# <p>빨리 html 크롤링을 하고 싶어요!</p>

# %% [markdown]
# **span**
#   * 문자열을 감싸고 있는 태그
#   * 문자열의 특정한 부분에 `css`같은 효과를 주기 위해 사용
#   * `<span> 내용 </span>`

# %%
# %%html
# <p>여기는 일반적인 문자열 입니다. <span style="color:red;">여기는</span> span이 약간 감쌌어요!</p>
# Out:
# <p>여기는 일반적인 문자열 입니다. <span style="color:red;">여기는</span> span이 약간 감쌌어요!</p>

# %% [markdown]
# **div**
# * 레이아웃을 구분해 놓기 위한 태그
# * 가장 많이 사용되는 태그
# * `<div> 각종 태그 및 텍스트 </div>`

# %%
# %%html
# <div>
#   <div>
#     <p>div 안쪽에 p가 있습니다.</p>
#   </div>
#   <div>
#     <div>
#       <p>또다른 div</p>
#     </div>
#   </div>
# </div>
# Out:
# <div>
#   <div>
#     <p>div 안쪽에 p가 있습니다.</p>
#   </div>
#   <div>
#     <div>
#       <p>또다른 div</p>
#     </div>
#   </div>
# </div>

# %% [markdown]
# **table**
# * 표를 그리기 위한 태그
# * 행과 열이 존재하는 테이블 모양을 나타낼 때 사용하는 태그
# * table을 구성하는 tag 정리
#   * `table` : 전체 테이블을 만들기 위한 태그
#   * `caption` : 테이블 제목을 만들기 위한 태그 ( 생략 가능 )
#   * `thead` : 테이블 항목(컬럼)을 표시하기 위한 태그( 생략 가능 )
#   * `tbody` : 테이블의 실제 데이터를 표시하기 위한 태그( 생략 가능 )
#   * `th` : 테이블 항목(컬럼)을 강조하기 위한 태그( `td`로 대체 가능.. 하지만 추천하지 않는다)
#   * `td` : 일반적으로 데이터를 집어넣기 위해 사용 ( 한 칸 )
#   * `tr` : 한 줄(행)을 만들기 위한 태그

# %%
# %%html
# <table border="1">
#   <caption>테이블 제목</caption>
#   <thead>
#     <tr>
#       <th>코드</th>
#       <th>회사명</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>00001</td>
#       <td>관광지 1</td>
#     </tr>
#     <tr>
#       <td>00002</td>
#       <td>관광지 2</td>
#     </tr>
#   </tbody>
# </table>
# Out:
# <table border="1">
#   <caption>테이블 제목</caption>
#   <thead>
#     <tr>
#       <th>코드</th>
#       <th>회사명</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>00001</td>
#       <td>관광지 1</td>
#     </tr>
#     <tr>
#       <td>00002</td>
#       <td>관광지 2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **ul, li**
# * 리스트를 나타내는 태그

# %%
# %%html
# <ul>
#   <li>data 1</li>
#   <li>data 2</li>
#   <li>data 3</li>
# </ul>
# Out:
# <ul>
#   <li>data 1</li>
#   <li>data 2</li>
#   <li>data 3</li>
# </ul>

# %% [markdown]
# 숫자 리스트로 표기

# %%
# %%html
# <ol>
#   <li>파랑</li>
#   <li>빨강</li>
#   <li>초록</li>
# <ol>
# Out:
# <ol>
#   <li>파랑</li>
#   <li>빨강</li>
#   <li>초록</li>
# <ol>

# %% [markdown]
# **a**
# * 굉장히 중요한 태그! - anchor 태그 덕분에 HyterText라는 이름이 붙은 것임!
# * **href** 속성에 이동할 URL 데이터를 집어 넣으면 된다.

# %%
# %%html
# <a href="https://www.naver.com" target="_blank">네이버로 이동</a>
# <a href="https://www.daum.net">다음으로 이동</a>
# <a href="https://www.google.com">구글로 이동</a>
# Out:
# <a href="https://www.naver.com" target="_blank">네이버로 이동</a>
# <a href="https://www.daum.net">다음으로 이동</a>
# <a href="https://www.google.com">구글로 이동</a>

# %% [markdown]
# **img**
# * 이미지를 표시하기 위한 태그
# * `src` 속성에 있는 이미지를 화면에 표시

# %%
# %%html
# <img src="data:image/png;base64,..." />
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# **input**
# * 사용자의 입력을 받기 위한 태그
# * ex) 검색창, 콤보박스, 드랍박스, 비밀번호 입력, 라디오 버튼, 체크박스 등등

# %%
# %%html
# <input type="text"></input>
# <input type="password" placeholder="비밀번호"></input>
# <input type="radio" name="data">남자</input>
# <input type="radio" name="data">여자</input>
# <input type="checkbox">checkbox1</input>
# <input type="checkbox">checkbox2</input>
# <input type="checkbox">checkbox3</input>
# Out:
# <input type="text"></input>
# <input type="password" placeholder="비밀번호"></input>
# <input type="radio" name="data">남자</input>
# <input type="radio" name="data">여자</input>
# <input type="checkbox">checkbox1</input>
# <input type="checkbox">checkbox2</input>
# <input type="checkbox">checkbox3</input>

# %% [markdown]
# **select, option**
# * 드랍다운(콤보박스) 형태로 선택을 할 수 있는 형태의 태그

# %%
# %%html
# <select>
#   <option>data 1</option>
#   <option>data 2</option>
# </select>
# Out:
# <select>
#   <option>data 1</option>
#   <option>data 2</option>
# </select>
