# %% [markdown]
# <a href="https://colab.research.google.com/github/dohyeon-kim012/WebScraping/blob/main/3.HTML%20%EC%8A%A4%ED%81%AC%EB%A0%88%EC%9D%B4%ED%95%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 스크레이핑 ( Scraping ) : 웹사이트에 있는 특정 정보를 추출하는 기술을 의미한다. 이를 이용해서 **타깃을 정해놓고** 웹사이트에 있는 정보를 쉽게 수집할 수 있다
# 크롤링 : 구글이나 네이버 등의 포털 사이트들이 불특정 다수의 웹사이트들의 정보를 **주기적으로** 가져오는 것
#     - sse, sso : 크롤링에 잘 해당되기 위한 방법

# %%
html_str = """
<html>
  <head>
    <title>안녕하세요</title>
  </head>
  <body>
    <div id="container">
      <p class='p1'>hello</p>
      <p>Bye</p>
    </div>
  </body>
</html>"""

# %% [markdown]
# html 문자열을 python에서 다루려면?
#
# --> `BeautifulSoup` 을 이용하여 HTML을 Element 객체화 시킬 수 있다
#     + 필요한 부분에 접근해서 필요한 데이터를 빼오면 된다

# %%
from bs4 import BeautifulSoup # 이상한 나라의 앨리스

# %%
soup = BeautifulSoup(html_str)
soup
# Out:
# <html>
# <head>
# <title>안녕하세요</title>
# </head>
# <body>
# <div id="container">
# <p class="p1">hello</p>
# <p>Bye</p>
# </div>
# </body>
# </html>

# %% [markdown]
# - `find( "태그 이름", "속성 값을 dict로 묶은 것" )` : 한 개만 찾기
#     ( 조건을 만족하는 첫 번째 엘리먼트만 가져옴 )
#
# - `fint_all` : 모두 찾기 ( 리스트로 나옴 )

# %%
soup.find_all
# Out:
# <bound method Tag.find_all of <html>
# <head>
# <title>안녕하세요</title>
# </head>
# <body>
# <div id="container">
# <p class="p1">hello</p>
# <p>Bye</p>
# </div>
# </body>
# </html>>

# %%
# div 중에 id가 container인 것 찾기
soup.find("div", {"id":"container"})
# Out:
# <div id="container">
# <p class="p1">hello</p>
# <p>Bye</p>
# </div>

# %%
# p 중에 클래스가 p1인 것 찾기
soup.find("p", {"class":"p1"})
# Out:
# <p class="p1">hello</p>

# %%
# p를 "모두 찾기"
soup.find_all("p")
# Out:
# [<p class="p1">hello</p>, <p>Bye</p>]

# %% [markdown]
# 텍스트 ( text ) 꺼내오기

# %%
p_p1 = soup.find("p", {'class':'p1'})
p_p1.text
# Out:
# 'hello'

# %% [markdown]
# Bye 만 꺼내기

# %%
p_Bye = soup.find_all("p")[-1]
p_Bye.text
# Out:
# 'Bye'

# %%
soup.find_all("p")[1].text
# Out:
# 'Bye'

# %% [markdown]
# 형제관계를 이용 - 특수한 상황에서만 사용할 것
#
# `nextSibling`을 1개만 넣으면 `</n>` 출력됨
# --> 계획문자인 `</n>` 도 엘리먼트로 치기 때문에

# %%
p_p1.nextSibling.nextSibling.text
# Out:
# 'Bye'

# %%
p_p1.nextSibling
# Out:
# '\n'

# %% [markdown]
# 선택자 ( selector ) 를 사용하여 추출하기

# %%
soup
# Out:
# <html>
# <head>
# <title>안녕하세요</title>
# </head>
# <body>
# <div id="container">
# <p class="p1">hello</p>
# <p>Bye</p>
# </div>
# </body>
# </html>

# %% [markdown]
# - `soup.select` : 선택자에 의해 엘리먼트를 여러 개 선택
# - `soup.select_one` : 선택자에 의해 엘리먼트를 한 개만 선택

# %%
soup.select_one("#container > .p1")
# Out:
# <p class="p1">hello</p>

# %%
soup.select("#container > p")[1]
# Out:
# <p>Bye</p>

# %%
soup.select("#container > p")[-1].text
# Out:
# 'Bye'

# %% [markdown]
# ## 속성값 추출하기
#
# 엘리먼트를 찾고, 원하는 속성명을 적으면 속성값을 찾을 수 있다

# %%
soup.select_one(".p1")
# Out:
# <p class="p1">hello</p>

# %%
soup.select_one(".p1")['class']
# Out:
# ['p1']

# %%
soup.select_one(".p1").get('class')
# Out:
# ['p1']

# %% [markdown]
# # 네이버 환율 정보 가져오기
#
# - 웹에 접속을 해야 하기 때문에 `requests` 모듈이 필요
# - html 문서를 가져오고 Element 객체화 시키기 위해 `BeautifulSoup` 필요

# %%
# from urllib.request import urlopen
import requests # urlopen = requests
from bs4 import BeautifulSoup

# %%
url = "https://finance.naver.com/marketindex/"

# %%
response = requests.get(url)
data = response.content # 접속한 웹 사이트의 html 코드 가져오기
data
# Out:
# b'\n<script language=javascript src="/template/head_js.nhn?referer=info.finance.naver.com&menu=marketindex&submenu=market"></script>\n<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/info/jindo.min.ns.1.5.3.euckr.js"></script>\n<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/jindo.1.5.3.element-text-patch.js"></script>\n\n\n\t\n\t\n\t<div id="container" style="padding-bottom:0px;">\n\t\n\n\t\t\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t\t<div class="market_include">\n\t<div class="market_data">\n\t\t<div class="market1">\n\t\t\t<div class="title">\n\t\t\t\t<h2 class="h_market1"><span>\xc8\xaf\xc0\xfc \xb0\xed\xbd\xc3 \xc8\xaf\xc0\xb2</span></h2>\n\t\t\t</div>\n\t\t\t<!-- data -->\n\t\t\t<div class="data">\n\t\t\t\t<ul class="data_lst" id="exchangeList">\n\t\t\t\t\n\t\t\t\t    \n\t\t\t\t         \n\t\t\t\t         \n\t\t\t\t         \n\t\t\t\t         \t\t\t\t         \t\t\t         \n\t\t\t\t        \n\t\t\t\t\t\n\t\t\t\t \t<li class="on">\n\t\t\t\t\t<a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" class="head usd" onClick="clickcr(this, \'fr1.usdt\', \'\', \'\', event);">\n\t\t\t\t\t\t<h3 class="h_lst"><span class="blind">\xb9\xcc\xb1\xb9 USD</span></h3>\n\t\t\t\t\t\t\n\t\t\t\t\t\t \n\t\t\t\t\t\t\n\t\t\t\t         \t\n\t\t\t\t         \t\n\t\t\t\t         \t\t\t\t\t         \t\t\t         \n\t\t\t\t     \t    \n\t\t\t\t\t\t<div class="head_info point_dn">\n\t\t\t\t\t\t\t<span class="value">1,147.50</span>\n\t\t\t\t\t\t\t<span class="txt_krw"><span class="blind">\xbf\xf8</span></span>\n\t\t\t\t\t\t\t<span class="change"> 1.00</span>\n\t\t\t\t\t\t\t<span class="blind">\xc7\xcf\xb6\xf4</span>\n\t\t\t\t\t\t</div>\n\t\t\t\t\t</a>\n\t\t\t\t\t\n\t\t\t\t\t<a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" class="graph_img" onClick="clickcr(this, \'fr1.usdc\', \'\', \'\', event);">\n\t\t\t\t\t\t<img src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDKRW.png" alt="" width="295" height="153">\n\t\t\t\t\t</a>\n\t\t\t\t\t\n\t\t\t\t\t<div class="graph_info">\n\t\t\t\t\t\t<span class="time">2021.07.12 15:54</span>\n\t\t\t\t\t\t<span class="source">\xc7\xcf\xb3\xaa\xc0\xba\xc7\xe0 \xb1\xe2\xc1\xd8</span>\n\t\t\t\t\t\t<span class="count">\xb0\xed\xbd\xc3\xc8\xb8\xc2\xf7<span class="num">182</span>\xc8\xb8</span>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t</div>\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t</li>\n\t\t\t\t\n\t\t\t\t    \n\t\t\t\t         \n\t\t\t\t         \n\t\t\t\t         \n\t\t\t\t         \t\t\t\t         \t\t\t         \n\t\t\t\t        \n\t\t\t\t\t\n\t\t\t\t \t<li class="">\n\t\t\t\t\t<a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_JPYKRW" class="head jpy" onClick="clickcr(this, \'fr1.jpyt\', \'\', \'\', event);">\n\t\t\t\t\t\t<h3 class="h_lst"><span class="blind">\xc0\xcf\xba\xbb JPY(100\xbf\xa3)</span></h3>\n\t\t\t\t\t\t\n\t\t\t\t\t\t \n\t\t\t\t\t\t\n\t\t\t\t         \t\n\t\t\t\t         \t\n\t\t\t\t         \t\t\t\t\t         \t\t\t         \n\t\t\t\t     \t    \n\t\t\t\t\t\t<div class="head_info point_dn">\n\t\t\t\t\t\t\t<span class="value">1,041.24</span>\n\t\t\t\t\t\t\t<span class="txt_krw"><span class="blind">\xbf\xf8</span></span>\n\t\t\t\t\t\t\t<span class="change"> 2.80</span>\n\t\t\t\t\t\t\t<span class="blind">\xc7\xcf\xb6\xf4</span>\n\t\t\t\t\t\t</div>\n\t\t\t\t\t</a>\n\t\t\t\t\t\n\t\t\t\t\t<a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_JPYKRW" class="graph_img" onClick="clickcr(this, \'fr1.jpyc\', \'\', \'\', event);">\n\t\t\t\t\t\t<img src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_JPYKRW.png" alt="" width="295" height="153">\n\t\t\t\t\t</a>\n\t\t\t\t\t\n\t\t\t\t\t<div class="graph_info">\n\t\t\t\t\t\t<span class="time">2021.07.12 15:54</span>\n\t\t\t\t\t\t<span class="source">\xc7\xcf\xb3\xaa\xc0\xba\xc7\xe0 \xb1\xe2\xc1\xd8</span>\n\t\t\t\t\t\t<span class="count">\xb0\xed\xbd\xc3\xc8\xb8\xc2\xf7<span class="num">182</span>\xc8\xb8</span>\n\t ...

# %%
soup = BeautifulSoup(data)
soup
# Out:
# <html><head><script language="javascript" src="/template/head_js.nhn?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/jindo.1.5.3.element-text-patch.js" type="text/javascript"></script>
# </head><body><div id="container" style="padding-bottom:0px;">
# <div class="market_include">
# <div class="market_data">
# <div class="market1">
# <div class="title">
# <h2 class="h_market1"><span>환전 고시 환율</span></h2>
# </div>
# <!-- data -->
# <div class="data">
# <ul class="data_lst" id="exchangeList">
# <li class="on">
# <a class="head usd" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
# <div class="head_info point_dn">
# <span class="value">1,147.50</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 1.00</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2021.07.12 15:54</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">182</span>회</span>
# </div>
# </li>
# <li class="">
# <a class="head jpy" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_JPYKRW" onclick="clickcr(this, 'fr1.jpyt', '', '', event);">
# <h3 class="h_lst"><span class="blind">일본 JPY(100엔)</span></h3>
# <div class="head_info point_dn">
# <span class="value">1,041.24</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 2.80</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_JPYKRW" onclick="clickcr(this, 'fr1.jpyc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_JPYKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2021.07.12 15:54</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">182</span>회</span>
# </div>
# </li>
# <li class="">
# <a class="head eur" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_EURKRW" onclick="clickcr(this, 'fr1.eurt', '', '', event);">
# <h3 class="h_lst"><span class="blind">유럽연합 EUR</span></h3>
# <div class="head_info point_dn">
# <span class="value">1,360.88</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 1.07</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_EURKRW" onclick="clickcr(this, 'fr1.eurc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_EURKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2021.07.12 15:54</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">182</span>회</span>
# </div>
# </li>
# <li class="">
# <a class="head cny" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_CNYKRW" onclick="clickcr(this, 'fr1.cnyt', '', '', event);">
# <h3 class="h_lst"><span class="blind">중국 CNY</span></h3>
# <div class="head_info point_up">
# <span class="value">177.11</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change">0.17</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_CNYKRW" onclick="clickcr(this, 'fr1.cnyc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_CNYKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2021.07.12 15:54</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">182</span>회</span>
# </div>
# </li>
# </ul>
# </div>
# <!-- //data -->
# </div>
# <div class="market2">
# <div class="title">
# <h2 class="h_market2"><span>국제 시장 환율</span></h2>
# </div>
# <!-- data -->
# <div class="data">
# <ul class="data_lst" id="worldExchangeList">
# <li class="on">
# <a class="head jpy_usd" href="/marketindex/worldExchangeDetail.nhn?marketindexCd=FX_USDJPY" onclick="clickcr(this, 'fr2.jpyut', '', '', event);">
# <h3 class="h_lst"><span class="blind">달러/일본 엔</span></h3>
# <div class="head_info point_dn">
# <span class="value">110.0900</span>
# <span class="txt_jpy"><span class="blind">엔</span></span>
# <span class="change"> 0.0500</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldExchangeDetail.nhn?marketindexCd=FX_USDJPY" onclick="clickcr(this, 'fr2.jpyuc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDJPY.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2021.07.10</span>
# <span class="source">모닝스타 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head usd_eur" href="/marketindex/worldExchangeDetail.nhn?marketindexCd=FX_EURUSD" onclick="clickcr(this, 'fr2.eurdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">유로/달러</span></h3>
# <div class="head_info point_up">
# <span class="value">1.1879</span>
# <span class="txt_usd"><span class="blind">달러</span></span>
# <span class="change">0.0015</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldExchangeDetail.nhn?marketindexCd=FX_EURUSD" onclick="clickcr(this, 'fr2.eurdc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_EURUSD.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2021.07.10</span>
# <span class="source">모닝스타 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head usd_gbp" href="/marketindex/worldExchangeDetail.nhn?marketindexCd=FX_GBPUSD" onclick="clickcr(this, 'fr2.gbpdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">영국 파운드/달러</span></h3>
# <div class="head_info point_up">
# <span class="value">1.3915</span>
# <span class="txt_usd"><span class="blind">달러</span></span>
# <span class="change">0.0080</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldExchangeDetail.nhn?marketindexCd=FX_GBPUSD" onclick="clickcr(this, 'fr2.gbpdc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_GBPUSD.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2021.07.10</span>
# <span class="source">모닝스타 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head usd_idx" href="/marketindex/worldExchangeDetail.nhn?marketindexCd=FX_USDX" onclick="clickcr(this, 'fr2.indt', '', '', event);">
# <h3 class="h_lst"><span class="blind">달러인덱스</span></h3>
# <div class="head_info point_dn">
# <span class="value">92.1100</span>
# <span class="change"> 0.2900</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldExchangeDetail.nhn?marketindexCd=FX_USDX" onclick="clickcr(this, 'fr2.indc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDX.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2021.07.09</span>
# <span class="source">ICE 기준</span>
# </div>
# </li>
# </ul>
# </div>
# <!-- //data -->
# </div>
# <div class="market3">
# <div class="title">
# <h2 class="h_market3"><span>유가·금시세</span></h2>
# </div>
# <!-- data -->
# <div class="data">
# <ul class="data_lst" id="oilGoldList">
# <li class="on">
# <a class="head wti" href="/marketindex/worldOilDetail.nhn?marketindexCd=OIL_CL&amp;fdtc=2" onclick="clickcr(this, 'fr3.wtit', '', '', event);">
# <h3 class="h_lst"><span class="blind">WTI</span></h3>
# <div class="head_info point_up">
# <span class="value">74.56</span>
# <span class="txt_usd"><span class="blind">달러</span></span>
# <span class="change">1.62</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldOilDetail.nhn?marketindexCd=OIL_CL&amp;fdtc=2" onclick="clickcr(this, 'fr3.wtic', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/OIL_CL.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2021.07.09</span>
# <span class="source">NYMEX(뉴욕상업거래소) 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head gasoline" href="/marketindex/oilDetail.nhn?marketindexCd=OIL_GSL" onclick="clickcr(this, 'fr3.oilt', '', '', event);">
# <h3 class="h_lst"><span class="blind">휘발유</span></h3>
# <div class="head_info point_up">
# <span class="value">1625.85</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change">1.25</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/oilDetail.nhn?marketindexCd=OIL_GSL" onclick="clickcr(this, 'fr3.oilc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/OIL_GSL.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2021.07.12</span>
# <span class="source">한국석유공사 Opinet 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head gold_inter" href="/marketindex/worldGoldDetail.nhn?marketindexCd=CMDT_GC&amp;fdtc=2" onclick="clickcr(this, 'fr3.agoldt', '', '', event);">
# <h3 class="h_lst"><span class="blind">국제 금</span></h3>
# <div class="head_info point_up">
# <span class="value">1810.0</span>
# <span class="txt_usd"><span class="blind">달러</span></span>
# <span class="change">10.40</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldGoldDetail.nhn?marketindexCd=CMDT_GC&amp;fdtc=2" onclick="clickcr(this, 'fr3.agoldc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/CMDT_GC.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2021.07.09</span>
# <span class="source">COMEX(뉴욕상품거래소) 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head gold_domestic" href="/marketindex/goldDetail.nhn" onclick="clickcr(this, 'fr3.kgoldt', '', '', event);">
# <h3 class="h_lst"><span class="blind">국내 금</span></h3>
# <div class="head_info point_dn">
# <span class="value">66399.39</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 164.11</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/goldDetail.nhn" onclick="clickcr(this, 'fr3.kgoldc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/CMDT_GD.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2021.07.12 15:53</span>
# <span class="source">신한은행 기준</span>
# 							(<span class="num">150</span>회차)
# 					</div>
# </li>
# </ul>
# </div>
# <!-- //data -->
# </div>
# </div>
# </div>
# <div class="marketindex_content" id="content">
# <div class="section_news">
# <h3 class="h_news2"><span>주요 뉴스</span></h3>
# <div class="list_area">
# <ul>
# <li>
# <p><a href="/marketindex/news/newsRead.nhn?officeId=215&amp;articleId=0000970869&amp;category=" onclick="clickcr(this, 'mhn.list', '215_0000970869', '0', event);">베트남, 건설 원자재 가격폭등으로 부동산 </a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>07.12 08:41</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.nhn?officeId=018&amp;articleId=0004982045&amp;category=" onclick="clickcr(this, 'mhn.list', '018_0004982045', '1', event);">"델타변이에 금값↑…연준 긴축 시 귀금속 </a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>07.12 08:18</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.nhn?officeId=018&amp;articleId=0004982041&amp;category=" onclick="clickcr(this, 'mhn.list', '018_0004982041', '2', event);">[외환브리핑]델타 공포 이겨내고 위험선호 </a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>07.12 08:15</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.nhn?officeId=417&amp;articleId=0000713787&amp;category=" onclick="clickcr(this, 'mhn.list', '417_0000713787', '3', event);">[오늘의 환율전망] 위험자산 선호 재부각…</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>07.12 07:33</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.nhn?officeId=029&amp;articleId=0002686292&amp;category=" onclick="clickcr(this, 'mhn.list', '029_0002686292', '4', event);">경쟁 심화·원자재 부담에 규제까지…하반기 </a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>07.11 18:16</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.nhn?officeId=421&amp;articleId=0005469329&amp;category=" onclick="clickcr(this, 'mhn.list', '421_0005469329', '5', event);">美 연준 "원자재 부족-구인난에 경제 회복</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>07.10 07:58</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.nhn?officeId=018&amp;articleId=0004980406&amp;category=" onclick="clickcr(this, 'mhn.list', '018_0004980406', '6', event);">[국제유가]OPEC+ 합의 불발 여진…급등</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>07.10 05:09</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.nhn?officeId=001&amp;articleId=0012516206&amp;category=" onclick="clickcr(this, 'mhn.list', '001_0012516206', '7', event);">[뉴욕유가] OPEC+ 산유량 협상 불확실</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>07.10 04:21</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.nhn?officeId=421&amp;articleId=0005469146&amp;category=" onclick="clickcr(this, 'mhn.list', '421_0005469146', '8', event);">중국 지급준비율 0.5%p 내려 8.9%…</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>07.09 20:12</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.nhn?officeId=009&amp;articleId=0004822013&amp;category=" onclick="clickcr(this, 'mhn.list', '009_0004822013', '9', event);">中 인민은행, 원자재 값 급등에 지준율 0</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>07.09 19:11</span>
# </li>
# </ul>
# </div>
# <a class="btn_more" href="/marketindex/news/newsList.nhn" onclick="clickcr(this, 'mhn.more', '', '', event);"><img alt="더보기" height="18" src="https://ssl.pstatic.net/static/nfinance/btn_more.gif" width="34"/></a>
# </div>
# <div class="tab_default1" id="tab_section">
# <ul>
# <li class="on"><a href="./?tabSel=exchange#tab_section" onclick="clickcr(this, 'mtb.exnoti', '', '', event);"><span class="tab1">환전고시 환율</span></a></li>
# <li class=""><a href="./?tabSel=worldExchange#tab_section" onclick="clickcr(this, 'mtb.interex', '', '', event);"><span class="tab2">국제시장 환율</span></a></li>
# <li class=""><a href="./?tabSel=gold#tab_section" onclick="clickcr(this, 'mtb.oilgold', '', '', event);"><span class="tab3">유가 금시세</span></a></li>
# <li class=""><a href="./?tabSel=materials#tab_section" onclick="clickcr(this, 'mtb.material', '', '', event);"><span class="tab4">원자재</span></a></li>
# </ul>
# <h2 class="blind">환전고시 환율</h2>
# </div>
# <div class="section_calculator">
# <h3 class="h_calculator"><span>환율계산기 (매매기준율 기준)</span></h3>
# <div class="calculator">
# <div class="inner">
# <div class="input">
# <div class="selectbox-noscript" id="sInput">
# <select class="selectbox-source" id="select_from">
# <option label="1" value="1">대한민국 원 KRW</option>
# <option class="selectbox-default" label="1" selected="selected" value="1147.5"> 미국 달러 USD</option>
# <option label="1" value="1147.5"> 미국 달러 USD</option>
# <option label="1" value="1360.88"> 유럽연합 유로 EUR</option>
# <option label="100" value="10.4124"> 일본 엔 JPY</option>
# <option label="1" value="177.11"> 중국 위안 CNY</option>
# <option label="1" value="147.74"> 홍콩 달러 HKD</option>
# <option label="1" value="40.96"> 대만 달러 TWD</option>
# <option label="1" value="1593.25"> 영국 파운드 GBP</option>
# <option label="1" value="2980.44"> 오만 리알 OMR</option>
# <option label="1" value="919.99"> 캐나다 달러 CAD</option>
# <option label="1" value="1253.62"> 스위스 프랑 CHF</option>
# <option label="1" value="133.51"> 스웨덴 크로나 SEK</option>
# <option label="1" value="856.95"> 호주 달러 AUD</option>
# <option label="1" value="800.15"> 뉴질랜드 달러 NZD</option>
# <option label="1" value="52.8"> 체코 코루나 CZK</option>
# <option label="1" value="1.53"> 칠레 페소 CLP</option>
# <option label="1" value="132.57"> 터키 리라 TRY</option>
# <option label="1" value="0.4"> 몽골 투그릭 MNT</option>
# <option label="1" value="350.0"> 이스라엘 세켈 ILS</option>
# <option label="1" value="183.0"> 덴마크 크로네 DKK</option>
# <option label="1" value="132.02"> 노르웨이 크로네 NOK</option>
# <option label="1" value="305.93"> 사우디아라비아 리얄 SAR</option>
# <option label="1" value="3815.97"> 쿠웨이트 디나르 KWD</option>
# <option label="1" value="3043.44"> 바레인 디나르 BHD</option>
# <option label="1" value="312.4"> 아랍에미리트 디르함 AED</option>
# <option label="1" value="1618.48"> 요르단 디나르 JOD</option>
# <option label="1" value="73.09"> 이집트 파운드 EGP</option>
# <option label="1" value="35.19"> 태국 바트 THB</option>
# <option label="1" value="848.77"> 싱가포르 달러 SGD</option>
# <option label="1" value="273.87"> 말레이시아 링깃 MYR</option>
# <option label="100" value="0.0794"> 인도네시아 루피아 IDR</option>
# <option label="1" value="309.88"> 카타르 리얄 QAR</option>
# <option label="1" value="2.68"> 카자흐스탄 텡게 KZT</option>
# <option label="1" value="848.77"> 브루나이 달러 BND</option>
# <option label="1" value="15.41"> 인도 루피 INR</option>
# <option label="1" value="7.19"> 파키스탄 루피 PKR</option>
# <option label="1" value="13.53"> 방글라데시 타카 BDT</option>
# <option label="1" value="22.9"> 필리핀 페소 PHP</option>
# <option label="1" value="57.58"> 멕시코 페소 MXN</option>
# <option label="1" value="218.17"> 브라질 레알 BRL</option>
# <option label="100" value="0.0499"> 베트남 동 VND</option>
# <option label="1" value="80.08"> 남아프리카 공화국 랜드 ZAR</option>
# <option label="1" value="15.41"> 러시아 루블 RUB</option>
# <option label="1" value="3.83"> 헝가리 포린트 HUF</option>
# <option label="1" value="299.47"> 폴란드 즈워티 PLN</option>
# </select>
# <div class="selectbox-box" onclick="clickcr(this, 'exl*c.clist1', '', '', event);">
# <div class="selectbox-label"></div>
# </div>
# <div class="selectbox-layer ly_calculator">
# <div class="selectbox-list"></div>
# </div>
# </div>
# <div class="input_area" id="input_from">
# <input id="input_from_money" maxlength="10" onclick="clickcr(this, 'exl*c.unit1', '', '', event);" onfocus="changeActiveInput('from', 'to'); return false;" onkeyup="calcExchange('from', 'to', 'on', event);" type="text" value="1"/>
# <img alt="" height="13" id="img_from_monetary" src="https://ssl.pstatic.net/static/nfinance/img_money_USD.gif" width="26"/>
# </div>
# </div>
# <div class="same"><img alt="" height="15" src="https://ssl.pstatic.net/static/nfinance/ico_same.gif" width="28"/></div>
# <div class="view">
# <div class="selectbox-noscript" id="sView">
# <select class="selectbox-source" id="select_to">
# <option class="selectbox-default" label="1" value="1">대한민국 원 KRW</option>
# <option label="1" value="1">대한민국 원 KRW</option>
# <option label="1" value="1147.5">미국 달러 USD</option>
# <option label="1" value="1360.88">유럽연합 유로 EUR</option>
# <option label="100" value="10.4124">일본 엔 JPY</option>
# <option label="1" value="177.11">중국 위안 CNY</option>
# <option label="1" value="147.74">홍콩 달러 HKD</option>
# <option label="1" value="40.96">대만 달러 TWD</option>
# <option label="1" value="1593.25">영국 파운드 GBP</option>
# <option label="1" value="2980.44">오만 리알 OMR</option>
# <option label="1" value="919.99">캐나다 달러 CAD</option>
# <option label="1" value="1253.62">스위스 프랑 CHF</option>
# <option label="1" value="133.51">스웨덴 크로나 SEK</option>
# <option label="1" value="856.95">호주 달러 AUD</option>
# <option label="1" value="800.15">뉴질랜드 달러 NZD</option>
# <option label="1" value="52.8">체코 코루나 CZK</option>
# <option label="1" value="1.53">칠레 페소 CLP</option>
# <option label="1" value="132.57">터키 리라 TRY</option>
# <option label="1" value="0.4">몽골 투그릭 MNT</option>
# <option label="1" value="350.0">이스라엘 세켈 ILS</option>
# <option label="1" value="183.0">덴마크 크로네 DKK</option>
# <option label="1" value="132.02">노르웨이 크로네 NOK</option>
# <option label="1" value="305.93">사우디아라비아 리얄 SAR</option>
# <option label="1" value="3815.97">쿠웨이트 디나르 KWD</option>
# <option label="1" value="3043.44">바레인 디나르 BHD</option>
# <option label="1" value="312.4">아랍에미리트 디르함 AED</option>
# <option label="1" value="1618.48">요르단 디나르 JOD</option>
# <option label="1" value="73.09">이집트 파운드 EGP</option>
# <option label="1" value="35.19">태국 바트 THB</option>
# <option label="1" value="848.77">싱가포르 달러 SGD</option>
# <option label="1" value="273.87">말레이시아 링깃 MYR</option>
# <option label="100" value="0.0794">인도네시아 루피아 IDR</option>
# <option label="1" value="309.88">카타르 리얄 QAR</option>
# <option label="1" value="2.68">카자흐스탄 텡게 KZT</option>
# <option label="1" value="848.77">브루나이 달러 BND</option>
# <option label="1" value="15.41">인도 루피 INR</option>
# <option label="1" value="7.19">파키스탄 루피 PKR</option>
# <option label="1" value="13.53">방글라데시 타카 BDT</option>
# <option label="1" value="22.9">필리핀 페소 PHP</option>
# <option label="1" value="57.58">멕시코 페소 MXN</option>
# <option label="1" value="218.17">브라질 레알 BRL</option>
# <option label="100" value="0.0499">베트남 동 VND</option>
# <option label="1" value="80.08">남아프리카 공화국 랜드 ZAR</option>
# <option label="1" value="15.41">러시아 루블 RUB</option>
# <option label="1" value="3.83">헝가리 포린트 HUF</option>
# <option label="1" value="299.47">폴란드 즈워티 PLN</option>
# </select>
# <div class="selectbox-box" onclick="clickcr(this, 'exl*c.clist2', '', '', event);">
# <div class="selectbox-label"></div>
# </div>
# <div class="selectbox-layer ly_calculator">
# <div class="selectbox-list"></div>
# </div>
# </div>
# <div class="input_area" id="input_to">
# <input id="input_to_money" maxlength="10" onclick="clickcr(this, 'exl*c.unit2', '', '', event);" onfocus="changeActiveInput('to', 'from'); return false;" onkeyup="calcExchange('to', 'from', 'on', event);" type="text"/>
# <img alt="" height="13" id="img_to_monetary" src="https://ssl.pstatic.net/static/nfinance/img_money_KRW.gif" width="26"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="section_exchange">
# <div id="section_ex1">
# <h3 class="blind" id="exchange1">환전 고시 환율</h3>
# <div class="exchange_info">
# <span class="date">2021.07.12 15:54</span>
# <span class="standard">하나은행 기준</span>
# <span class="round">고시회차 <em>182</em>회</span>
# </div>
# <iframe frameborder="0" height="1378px" id="frame_ex1" marginheight="0" marginwidth="0" scrolling="no" src="/marketindex/exchangeList.nhn" title="환전 고시 환율" width="100%"></iframe>
# </div>
# <ul class="tbl_info">
# <li>통화명과 심볼은 앞에 위치한 통화에 1이 생략된 형태로, 달러/일본 엔(심볼: USDJPY)인 경우 1 USD(달러)가 JPY(일본 엔)으로 얼마인가를 의미합니다.</li>
# </ul>
# </div>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/jindoComponent/jindo.Component.1.0.3.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/jindoComponent/jindo.UIComponent.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/jindoComponent/jindo.HTMLComponent.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/jindoComponent/jindo.Timer.1.0.3.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/jindoComponent/jindo.LayerManager.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/jindoComponent/jindo.LayerPosition.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/jindoComponent/jindo.RolloverArea.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/jindoComponent/jindo.RolloverClick.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/jindoComponent/jindo.SelectBox.1.0.1.js" type="text/javascript"></script>
# <script charset="euckr" language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/jindoComponent/jindo.TextRange.1.0.1.js" type="text/javascript"></script>
# <script charset="euckr" language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/jindoComponent/jindo.WatchInput.1.0.1.js" type="text/javascript"></script>
# <script charset="euckr" language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/jindoComponent/jindo.Formatter.1.1.0.js" type="text/javascript"></script>
# <script charset="euckr" language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/jindoComponent/jindo.NumberFormatter.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/exchange.js" type="text/javascript"></script>
# <script type="text/javascript">
# // exchangeDetail.jsp에도 동일 스크립트 있음 - 로딩시 디자인이 0.5초간 디자인이 안뜬다는 이슈로 include하지 않고 같은 스크립트를 두벌로 관리함
#
# //환율 계산
# function calcExchange(str1, str2, cssOn, event) {
# 	var oEvent = event || window.event;
#     var sKeyCode = (undefined === oEvent) ? undefined : jindo.$Event(oEvent).key().keyCode;
#
# 	if (sKeyCode != 13 && sKeyCode != 27 && sKeyCode != 37 && sKeyCode != 38 && sKeyCode != 110 && sKeyCode != 229) {
# 		if (str1 == '' && str2 == '') {
# 			if (jindo.$('input_to').className == 'input_area') {
# 				str1 = 'from';
# 				str2 = 'to';
# 			} else {
# 				str1 = 'to';
# 				str2 = 'from';
# 			}
# 		}
#
# 		var regExp = new RegExp("[^0-9\.\,]");
# 	    var sInputValue = jindo.$('input_' + str1 + '_money').value;
#
# 	    if(regExp.test(sInputValue)){
# 			alert('숫자, 소수점(.)만 입력하실 수 있습니다.');
# 			jindo.$('input_' + str1 + '_money').value = revertInputText(sInputValue);
# 			return false;
# 		}
#
# 		// 사용자가 입력한 콤마(,) 제거
# 	    if (sInputValue.substr(sInputValue.length - 1, 1) == ',') {
# 	    	jindo.$('input_' + str1 + '_money').value = revertInputText(sInputValue);
# 	    	return false;
# 	    }
#
# 		// 맨 앞에 있는 숫자 0 없애기
# 		if (sInputValue == '0' || sInputValue == '.' || sInputValue == ',') {
# 			jindo.$('input_' + str1 + '_money').value = revertInputText(sInputValue);
# 			return false;
# 		}
#
# 		// 소수점 2개가 없도록
# 		var match = sInputValue.match(/\./g);
# 		if (match != null && match.length >= 2) {
# 			jindo.$('input_' + str1 + '_money').value = revertInputText(sInputValue);
# 			return false;
# 		}
#
# 		// 소수점을 입력한 경우, 일단 대기
# 		var pointPosIndex = sInputValue.indexOf('.');
# 		if (pointPosIndex != -1 && pointPosIndex == sInputValue.length - 1) {
# 			return false;
# 		}
#
# 		// 소수점 2자리 유지
# 		if (pointPosIndex != -1 && sInputValue.substring(pointPosIndex + 1, sInputValue.length).length > 2) {
# 			jindo.$('input_' + str1 + '_money').value = revertInputText(sInputValue);
# 			return false;
# 		}
#
# 		var e_select_from	= jindo.$('select_'+str1);
# 		var e_select_to	= jindo.$('select_'+str2);
#
# 		var input_from_money	= jindo.$('input_'+str1+'_money').value ;
# 		var input_from		= e_select_from.options[e_select_from.selectedIndex].value ;
# 		var input_to		= e_select_to.options[e_select_to.selectedIndex].value ;
# 		var unit_from	= e_select_from.options[e_select_from.selectedIndex].text ;
# 		var unit_to		= e_select_to.options[e_select_to.selectedIndex].text ;
# 		input_from_money = input_from_money.replace(/ |,|\t/g, "") ;
# 		input_from	= input_from.replace(/ |,|\t/g, "") ;
# 		input_to	= input_to.replace(/ |,|\t/g, "") ;
# 		unit_from = unit_from.substr(unit_from.length-3, 3);
# 		unit_to = unit_to.substr(unit_to.length-3, 3);
#
# 		var str1_result = input_from_money * 1 ;
# 		var str1_str	= str1_result.toFixed(0) ;
# 		var str1_len = str1_str.length ;
# 		var str1_result_str = new String("") ;
#
# 		if(str1_str > str1_result)
# 			str1_str = new String(str1_str-1) ;
#
# 		if (str1_len >= 3) {
# 			for (i = str1_len - 3; i > 0; i-=3)
# 				str1_result_str = "," + str1_str.substr(i, 3) + str1_result_str ;
#
# 			str1_result_str = str1_str.substr(0, 3+i) + str1_result_str ;
#
# 			for (var i=0; i<input_from_money.length; i++) {
# 				if (input_from_money.substr(i,1) != '0') {
# 					input_from_money = input_from_money.substring(i,input_from_money.length) ;
# 					break;
# 				}
# 			}
#
# 			if (str1_str != input_from_money) {
# 				str1_result_str += str1_result.toFixed(input_from_money.split(".")[1].length).substr(str1_len, input_from_money.split(".")[1].length + 1) ;
# 			}
# 		} else
# 			str1_result_str = input_from_money ;
#
# 		var str2_result = input_from_money * input_from / input_to ;
# 		var str2_str	= str2_result.toFixed(0) ;
# 		var str2_len = str2_str.length ;
# 		var str2_result_str = new String("") ;
#
# 		if (str2_str > str2_result)
# 			str2_str = new String(str2_str-1) ;
#
# 		if (str2_len >= 3) {
# 			for (i = str2_len - 3; i > 0; i-=3)
# 				str2_result_str = "," + str2_str.substr(i, 3) + str2_result_str ;
#
# 			str2_result_str = str2_str.substr(0, 3+i) + str2_result_str ;
# 			str2_result_str += str2_result.toFixed(2).substr(str2_len, 3) ;
# 		} else
# 			str2_result_str = str2_result.toFixed(2) ;
#
# 		jindo.$('input_'+str1+'_money').value = str1_result_str;
# 		jindo.$('input_'+str2+'_money').value = str2_result_str;
# 		jindo.$('img_'+str1+'_monetary').src = "https://ssl.pstatic.net/static/nfinance/img_money_"+unit_from+".gif";
# 		jindo.$('img_'+str2+'_monetary').src = "https://ssl.pstatic.net/static/nfinance/img_money_"+unit_to+".gif";
# 		jindo.$Element(jindo.$('input_'+str1)).addClass("on");
# 		jindo.$Element(jindo.$('input_'+str2)).removeClass("on");
# 		if (cssOn == "off"){
# 			jindo.$Element(jindo.$('input_'+str1)).removeClass("on");
# 		}
# 	}
# }
#
# function revertInputText(sOrgText) {
# 	var sResult = sOrgText;
#
# 	if (sOrgText != '') {
# 		sResult = sOrgText.substr(0, sOrgText.length - 1);
# 	}
#
# 	return sResult;
# }
#
# jindo.$Fn(function(){
# 	chartMouseOverEvent('exchangeList');
#    }).attach(document, "domready");
# </script>
# </div>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/jindo_ellipse.js"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/util.js"></script>
# <script type="text/javascript">
#
# function ellipseTopNewsTitle() {
# 	jindo.EllipseText.factory(jindo.$$(".news_list ul li"), {nAssistWidth: 10});
# }
#
# var basicDates;
#
# function initDate() {
# 	basicDates = jindo.$H();
# 	basicDates.add('', '');
# 	basicDates.add('', '');
# 	basicDates.add('', '');
# 	basicDates.add('', '');
# 	basicDates.add('', '');
# 	basicDates.add('', '');
# }
#
# var basicDescriptions;
#
# function initDescription() {
# 	basicDescriptions = jindo.$H();
# 	basicDescriptions.add('CMDT_CDY','<em></em>  기준<span>단위:</span>');
# 	basicDescriptions.add('CMDT_PDY','<em></em>  기준<span>단위:</span>');
# 	basicDescriptions.add('CMDT_NG','<em></em>  기준<span>단위:</span>');
# 	basicDescriptions.add('CMDT_S','<em></em>  기준<span>단위:</span>');
# 	basicDescriptions.add('CMDT_C','<em></em>  기준<span>단위:</span>');
# 	basicDescriptions.add('CMDT_SB','<em></em>  기준<span>단위:</span>');
# }
#
# function setEvent(num, imgChartUrl){
# 	var parentElemnt = jindo.$$('.tbl_market')[num];
# 	var elementList = jindo.$$('tr',parentElemnt);
#
# 	jindo.$Fn(function(e){
# 		var elementListSize = elementList.length;
#
# 		for(var i = 0 ; i < elementListSize ; i ++)
# 		{
# 			var selectedElement = jindo.$Element(elementList[i]);
# 			var selectedClassName = selectedElement.className();
# 			if (selectedClassName != "") {
# 				selectedElement.removeClass(selectedClassName);
# 				selectedElement.addClass(selectedClassName.replace("on",""));
# 			}
# 		}
#
# 		var ele = jindo.$Element(jindo.$Event(e).currentElement);
# 		var linkUrl = jindo.$$.getSingle('a' , ele.$value()).href;
# 		var marketindexCd = linkUrl.split('=')[1];
# 		var className = ele.className();
# 		ele.removeClass(className);
# 		ele.addClass(className+" on");
# 		var graphElement = jindo.$Element(jindo.$$('.thum')[num]);
# 		graphElement.html('<a href=\"'+linkUrl+'\"><img src=\"https://ssl.pstatic.net/imgfinance/chart/marketindex/' + marketindexCd + '.png\" width=\"295\" height=\"153\" alt=""></a>');
#
# 		if (basicDates.hasKey(marketindexCd)) {
# 			jindo.$Element("basicDate").text(basicDates.$(marketindexCd));
# 		}
# 		if (basicDescriptions.hasKey(marketindexCd)) {
# 			jindo.$Element("basicDescription").html(basicDescriptions.$(marketindexCd));
# 		}
#
# 	}).attach(elementList, "mouseover");
# }
#
# jindo.$Fn(function(){
# 		initDate();
# 		initDescription();
# 		chartMouseOverEvent('exchangeList');
# 		chartMouseOverEvent('worldExchangeList');
# 		chartMouseOverEvent('oilGoldList');
# 		jindo.$$('title')[0].innerHTML = "시장지표 : 네이버 금융";
# }).attach(document, "domready");
#
# </script>
# <div class="aside" id="marketindex_aside">
# <div class="section_aside">
# <h3 class="h_interest"><span>국내시장금리</span></h3>
# <table class="tbl_exchange market" summary="국제시장 환율 리스트">
# <caption>국내시장금리</caption>
# <colgroup>
# <col width="94"/>
# <col width="50"/>
# <col width="75"/>
# </colgroup>
# <thead>
# <tr>
# <th>구분</th>
# <th>금리</th>
# <th>등락율</th>
# </tr>
# </thead>
# <tbody>
# <tr class="down">
# <th class="th_inter4"><a href="/marketindex/interestDetail.nhn?marketindexCd=IRR_CD91" onclick="clickcr(this, 'rid.local', 'IRR_CD91', '1', event);"><span>CD금리(91일)</span></a></th>
# <td>0.68</td>
# <td><img alt="하락" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_down.gif" width="7"/> 0.01</td>
# </tr>
# <tr class="up">
# <th class="th_inter1"><a href="/marketindex/interestDetail.nhn?marketindexCd=IRR_CALL" onclick="clickcr(this, 'met.8', 'IRR_CALL', '2', event);"><span>콜 금리</span></a></th>
# <td>0.52</td>
# <td><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 0.01</td>
# </tr>
# <tr class="up">
# <th class="th_inter2"><a href="/marketindex/interestDetail.nhn?marketindexCd=IRR_GOVT03Y" onclick="clickcr(this, 'met.8', 'IRR_GOVT03Y', '3', event);"><span>국고채 (3년)</span></a></th>
# <td>1.37</td>
# <td><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 0.02</td>
# </tr>
# <tr class="up">
# <th class="th_inter3"><a href="/marketindex/interestDetail.nhn?marketindexCd=IRR_CORP03Y" onclick="clickcr(this, 'met.8', 'IRR_CORP03Y', '4', event);"><span>회사채 (3년)</span></a></th>
# <td>1.87</td>
# <td><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 0.01</td>
# </tr>
# <tr class="same">
# <th class="th_inter5"><a href="/marketindex/interestDetail.nhn?marketindexCd=IRR_COFIXBAL" onclick="clickcr(this, 'met.8', 'IRR_COFIXBAL', '5', event);"><span>COFIX 잔액</span></a></th>
# <td>1.02</td>
# <td><img alt="보합" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_same2.gif" width="7"/> 0.00</td>
# </tr>
# <tr class="same">
# <th class="th_inter6"><a href="/marketindex/interestDetail.nhn?marketindexCd=IRR_COFIXNEW" onclick="clickcr(this, 'met.8', 'IRR_COFIXNEW', '6', event);"><span>COFIX 신규취급액</span></a></th>
# <td>0.82</td>
# <td><img alt="보합" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_same2.gif" width="7"/> 0.00</td>
# </tr>
# </tbody>
# </table>
# <table class="tbl_exchange tbl_exchange_v1 market" style="margin-top:10px;" summary="달러 인덱스">
# <caption>달러 인덱스</caption>
# <colgroup>
# <col width="88"/>
# <col width="46"/>
# <col width="66"/>
# </colgroup>
# <thead>
# <tr>
# <th>구분</th>
# <th>금리</th>
# <th>등락율</th>
# </tr>
# </thead>
# <tbody>
# <tr class="other_t1 down">
# <th class="th_inter7"><a href="/marketindex/worldExchangeDetail.nhn?marketindexCd=FX_USDX&amp;fdtc=4" onclick="clickcr(this, 'rid.dollar', 'FX_USDX', '', event);"><span>달러 인덱스</span></a></th>
# <td>92.1100</td>
# <td><img alt="하락" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_down.gif" width="7"/>  0.2900</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="section_aside">
# <div class="tab_search search3">
# <a href="#" onclick="clickcr(this, 'rch.1', '', '', event); return false;"><span>최근조회</span></a>
# <a href="#" onclick="clickcr(this, 'rch.3', '', '', event); return false;"><span>MY STOCK</span></a>
# </div>
# <h3 class="blind">최근조회</h3>
# <table class="tbl_search" summary="최근조회 리스트">
# <caption>최근조회</caption>
# <colgroup>
# <col/>
# <col width="55"/>
# <col width="87"/>
# </colgroup>
# <thead>
# <tr>
# <th>업체명</th>
# <th>거래량</th>
# <th>전일비</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <div class="more_info">
# <span>
# <a href="#" onclick="clickcr(this, 'rch.5', '', '', event); return false;"><img alt="이전" height="15" src="https://ssl.pstatic.net/static/nfinance/btn_prev2.gif" width="17"/></a>
# <a href="#" onclick="clickcr(this, 'rch.6', '', '', event); return false;"><img alt="다음" height="15" src="https://ssl.pstatic.net/static/nfinance/btn_next2.gif" width="17"/></a>
# </span>
# <a class="btn_more _mystock_more_info" href="#" onclick="javascript:openMyitemNew('https://finance.naver.com'); clickcr(this, 'rch.7', '', '', event);"><img alt="더보기" height="10" src="https://ssl.pstatic.net/static/nfinance/btn_more5.gif" width="33"/></a>
# </div>
# </div>
# <div class="section_aside">
# <h3 class="h_report"><span>경제분석 리포트 </span></h3>
# <ul class="list_report">
# <li><a href="/research/economy_read.nhn?nid=7328" onclick="clickcr(this, 'rer.list', '', '', event);">미 3대 증시는 전일 하락에 따른...</a></li>
# <li><a href="/research/economy_read.nhn?nid=7327" onclick="clickcr(this, 'rer.list', '', '', event);">금통위, 판단을 유보할 수 밖에 ...</a></li>
# <li><a href="/research/economy_read.nhn?nid=7325" onclick="clickcr(this, 'rer.list', '', '', event);">미국달러 강세, 환율 전망 상향</a></li>
# <li><a href="/research/economy_read.nhn?nid=7324" onclick="clickcr(this, 'rer.list', '', '', event);">미 증시는 고용지표 부진, 코로나...</a></li>
# <li><a href="/research/economy_read.nhn?nid=7323" onclick="clickcr(this, 'rer.list', '', '', event);">Today Chart:미국 소비자...</a></li>
# </ul>
# <a class="btn_more" href="/research/economy_list.nhn" onclick="clickcr(this, 'rer.more', '', '', event);"><img alt="경제분석 리포트 더보기" height="18" src="https://ssl.pstatic.net/static/nfinance/btn_more.gif" width="34"/></a>
# </div>
# </div>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/info/myStock.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210709092423/js/util.js" type="text/javascript"></script>
# <script language="javascript">
#
# function toggleTabSearch(e){
# 	var currentElement = jindo.$Element(jindo.$Event(e).currentElement);
# 	var parentElement = currentElement.parent();
# 	var id = currentElement.className();
# 	var order = parentElement.indexOf(currentElement) + 3;
# 	parentElement.className("tab_search search"+ order);
#
# 	// 페이징을 위해서 order값에 따라 최근조회인지 mystock인지 type을 저장
# 	if (order == 3) {
# 		currentType = "recent";
# 	} else {
# 		currentType = "mystock";
# 	}
# }
#
# jindo.$Fn(function(){
# 	if ('true' == 'true') {
# 		getStockRightMenuData('000000', 'recent', 1, 'https://finance.naver.com', 'https://ssl.pstatic.net/static/nfinance');
#
# 		var tabSearchArea = jindo.$$.getSingle('.tab_search');
# 		var moreInfoArea = jindo.$Element(jindo.$$.getSingle('.tbl_search')).next().$value();
#
# 		jindo.$Fn(function(e) {toggleTabSearch(e); getStockRightMenuData('000000', 'recent', 1, 'https://finance.naver.com', 'https://ssl.pstatic.net/static/nfinance'); }).attach(jindo.$$.getSingle('a' ,tabSearchArea), 'click');
# 		jindo.$Fn(function(e) {toggleTabSearch(e); getStockRightMenuData('000000', 'mystock', 1, 'https://finance.naver.com', 'https://ssl.pstatic.net/static/nfinance'); }).attach(jindo.$$('a' ,tabSearchArea)[1], 'click');
# 		jindo.$Fn(function(e) {updatePageForPaging (currentType, 'up', 'https://finance.naver.com', 'https://ssl.pstatic.net/static/nfinance'); }).attach(jindo.$$.getSingle('a', moreInfoArea), 'click');
# 		jindo.$Fn(function(e) {updatePageForPaging (currentType, 'down', 'https://finance.naver.com', 'https://ssl.pstatic.net/static/nfinance'); }).attach(jindo.$$('a', moreInfoArea)[1], 'click');
# 	}
#
# }).attach(document,"domready");
#
# function openMyitemNew(stockHost) {
# 	var selectedElement = jindo.$Element(jindo.$$.getSingle(".tab_search"));
# 	if (selectedElement != null) {
# 		if (selectedElement.hasClass("search1")) {
# 			document.location.href = stockHost + '/mystock/recentSearchItemList.nhn';
# 		} else {
# 			document.location.href = stockHost + '/mystock/itemList.nhn';
# 		}
# 	}
# }
#
# </script>
# </div>
# <div id="footer">
# <ul>
# <li class="first">
# <a href="https://www.naver.com/rules/service.html" onclick="clickcr(this, 'fot.service', '', '', event);" target="_blank">이용약관</a>
# </li>
# <li>
# <a href="/rules.nhn" onclick="clickcr(this, 'fot.policy', '', '', event);" target="_blank">금융게시판 운영원칙</a>
# </li>
# <li>
# <a href="https://www.naver.com/rules/privacy.html" onclick="clickcr(this, 'fot.privacy', '', '', event);" target="_blank"><strong>개인정보처리방침</strong></a>
# </li>
# <li>
# <a href="https://www.naver.com/rules/disclaimer.html" onclick="clickcr(this, 'fot.limit', '', '', event);" target="_blank">책임의 한계와 법적고지</a>
# </li>
# <li>
# <a href="https://help.naver.com/support/alias/contents2/finance/finance_1.naver" onclick="clickcr(this, 'fot.help', '', '', event);" target="_blank">금융 고객센터</a>
# </li>
# </ul>
# <p class="desc">네이버(주)가 제공하는 금융 정보는 각 콘텐츠 제공업체로부터 받는 투자 참고사항이며, 오류가 발생하거나 지연될 수 있습니다.<br/>네이버(주)와 콘텐츠 제공업체는 제공된 정보에 의한 투자 결과에 법적인 책임을 지지 않습니다. 게시된 정보는 무단으로 배포할 수 없습니다.</p>
# <address>
# <a class="logo" href="https://www.navercorp.com/" onclick="clickcr(this, 'fot.nhn', '', '', event);" target="_blank"><img alt="NAVER" height="11" src="https://ssl.pstatic.net/static/nfinance/2019/02/22/ci_naver.png" width="58"/></a>
# <em>Copyright ©</em>
# <a href="https://www.navercorp.com/" onclick="clickcr(this, 'fot.nhn', '', '', event);" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# </div>
# <script type="text/javascript">
# function isVisible(obj) {
#     if (obj == document) return true
#
#     if (!obj) return false
#     if (!obj.parentNode) return false
#     if (obj.style) {
#         if (obj.style.display == 'none') return false
#         if (obj.style.visibility == 'hidden') return false
#     }
#
#     if (window.getComputedStyle) {
#         var style = window.getComputedStyle(obj, "")
#         if (style.display == 'none') return false
#         if (style.visibility == 'hidden') return false
#     }
#
#     var style = obj.currentStyle
#     if (style) {
#         if (style['display'] == 'none') return false
#         if (style['visibility'] == 'hidden') return false
#     }
#
#     return isVisible(obj.parentNode)
# }
#
# function isChildOf(myobj, containerObj) {
# 	while(myobj != undefined) {
# 		if (myobj == document.body) {
# 			break;
# 		}
# 		if (myobj == containerObj) {
# 			return true;
# 		}
# 		myobj = myobj.parentElement;
# 	}
# 	return false;
# }
#
# function gnbLayerClose(e){
# 	var target = e.target ? e.target : e.srcElement;
# 	if (isVisible(document.getElementById('gnb_service_lyr')) || isVisible(document.getElementById('gnb_notice_lyr')) ||isVisible(document.getElementById('gnb_my_lyr')) ) {
# 		if (!isChildOf(target, document.getElementById('gnb'))) {
# 			gnbAllLayerClose();
# 		}
# 	}
# }
#
# var isIE = (navigator.userAgent.toLowerCase().indexOf("msie")!=-1 && window.document.all) ? true:false;
# if (isIE) {
# 	document.attachEvent('onmousedown', gnbLayerClose);
# } else {
# 	window.addEventListener('mousedown', gnbLayerClose);
# }
# </script>
# </body>
# </html>

# %% [markdown]
# `id`가 있으면 사용하는 것이 좋음
# -> 하나밖에 없는 값이기 때문

# %%
soup = BeautifulSoup(data)
exchange_list = soup.find("ul", {"id":"exchangeList"})
# 또는 soup.select_one("#exchangeList")
exchange_list
# Out:
# <ul class="data_lst" id="exchangeList">
# <li class="on">
# <a class="head usd" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
# <div class="head_info point_dn">
# <span class="value">1,147.50</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 1.00</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2021.07.12 15:54</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">182</span>회</span>
# </div>
# </li>
# <li class="">
# <a class="head jpy" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_JPYKRW" onclick="clickcr(this, 'fr1.jpyt', '', '', event);">
# <h3 class="h_lst"><span class="blind">일본 JPY(100엔)</span></h3>
# <div class="head_info point_dn">
# <span class="value">1,041.24</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 2.80</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_JPYKRW" onclick="clickcr(this, 'fr1.jpyc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_JPYKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2021.07.12 15:54</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">182</span>회</span>
# </div>
# </li>
# <li class="">
# <a class="head eur" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_EURKRW" onclick="clickcr(this, 'fr1.eurt', '', '', event);">
# <h3 class="h_lst"><span class="blind">유럽연합 EUR</span></h3>
# <div class="head_info point_dn">
# <span class="value">1,360.88</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 1.07</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_EURKRW" onclick="clickcr(this, 'fr1.eurc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_EURKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2021.07.12 15:54</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">182</span>회</span>
# </div>
# </li>
# <li class="">
# <a class="head cny" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_CNYKRW" onclick="clickcr(this, 'fr1.cnyt', '', '', event);">
# <h3 class="h_lst"><span class="blind">중국 CNY</span></h3>
# <div class="head_info point_up">
# <span class="value">177.11</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change">0.17</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_CNYKRW" onclick="clickcr(this, 'fr1.cnyc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_CNYKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2021.07.12 15:54</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">182</span>회</span>
# </div>
# </li>
# </ul>

# %%
fin_list = exchange_list.find_all("li")
fin_list
# Out:
# [<li class="on">
#  <a class="head usd" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
#  <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
#  <div class="head_info point_dn">
#  <span class="value">1,147.50</span>
#  <span class="txt_krw"><span class="blind">원</span></span>
#  <span class="change"> 1.00</span>
#  <span class="blind">하락</span>
#  </div>
#  </a>
#  <a class="graph_img" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdc', '', '', event);">
#  <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDKRW.png" width="295"/>
#  </a>
#  <div class="graph_info">
#  <span class="time">2021.07.12 15:54</span>
#  <span class="source">하나은행 기준</span>
#  <span class="count">고시회차<span class="num">182</span>회</span>
#  </div>
#  </li>, <li class="">
#  <a class="head jpy" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_JPYKRW" onclick="clickcr(this, 'fr1.jpyt', '', '', event);">
#  <h3 class="h_lst"><span class="blind">일본 JPY(100엔)</span></h3>
#  <div class="head_info point_dn">
#  <span class="value">1,041.24</span>
#  <span class="txt_krw"><span class="blind">원</span></span>
#  <span class="change"> 2.80</span>
#  <span class="blind">하락</span>
#  </div>
#  </a>
#  <a class="graph_img" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_JPYKRW" onclick="clickcr(this, 'fr1.jpyc', '', '', event);">
#  <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_JPYKRW.png" width="295"/>
#  </a>
#  <div class="graph_info">
#  <span class="time">2021.07.12 15:54</span>
#  <span class="source">하나은행 기준</span>
#  <span class="count">고시회차<span class="num">182</span>회</span>
#  </div>
#  </li>, <li class="">
#  <a class="head eur" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_EURKRW" onclick="clickcr(this, 'fr1.eurt', '', '', event);">
#  <h3 class="h_lst"><span class="blind">유럽연합 EUR</span></h3>
#  <div class="head_info point_dn">
#  <span class="value">1,360.88</span>
#  <span class="txt_krw"><span class="blind">원</span></span>
#  <span class="change"> 1.07</span>
#  <span class="blind">하락</span>
#  </div>
#  </a>
#  <a class="graph_img" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_EURKRW" onclick="clickcr(this, 'fr1.eurc', '', '', event);">
#  <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_EURKRW.png" width="295"/>
#  </a>
#  <div class="graph_info">
#  <span class="time">2021.07.12 15:54</span>
#  <span class="source">하나은행 기준</span>
#  <span class="count">고시회차<span class="num">182</span>회</span>
#  </div>
#  </li>, <li class="">
#  <a class="head cny" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_CNYKRW" onclick="clickcr(this, 'fr1.cnyt', '', '', event);">
#  <h3 class="h_lst"><span class="blind">중국 CNY</span></h3>
#  <div class="head_info point_up">
#  <span class="value">177.11</span>
#  <span class="txt_krw"><span class="blind">원</span></span>
#  <span class="change">0.17</span>
#  <span class="blind">상승</span>
#  </div>
#  </a>
#  <a class="graph_img" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_CNYKRW" onclick="clickcr(this, 'fr1.cnyc', '', '', event);">
#  <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_CNYKRW.png" width="295"/>
#  </a>
#  <div class="graph_info">
#  <span class="time">2021.07.12 15:54</span>
#  <span class="source">하나은행 기준</span>
#  <span class="count">고시회차<span class="num">182</span>회</span>
#  </div>
#  </li>]

# %%
for fin in fin_list:
    print(fin.find("h3").text)
# Out:
# 미국 USD
# 일본 JPY(100엔)
# 유럽연합 EUR
# 중국 CNY

# %%
for fin in fin_list:
    # print("국가명 : {}".format(fin.find("h3", {"class":"h_lst"}).text))

    c_name = fin.find("h3", {"class":"h_lst"}).text
    # exchangeRate = soup.select("#exchangeList > li.on > a.head.usd > div > span.value")
    exchangeRate = fin.select_one("span.value").text
    change = fin.select_one("span.change").text
    updown = fin.select_one("span.blind").text

    print("국가명 : {}".format(c_name))
    print("환율 : {}".format(exchangeRate))
    print("변동 : {}".format(change))
    print("등락 : {}".format(updown))

    print()
# Out:
# 국가명 : 미국 USD
# 환율 : 1,147.50
# 변동 :  1.00
# 등락 : 미국 USD
#
# 국가명 : 일본 JPY(100엔)
# 환율 : 1,041.24
# 변동 :  2.80
# 등락 : 일본 JPY(100엔)
#
# 국가명 : 유럽연합 EUR
# 환율 : 1,360.88
# 변동 :  1.07
# 등락 : 유럽연합 EUR
#
# 국가명 : 중국 CNY
# 환율 : 177.11
# 변동 : 0.17
# 등락 : 중국 CNY

# %% [markdown]
# 문제점!
# 1. `환율`과 `변동`은 숫자가 아닌 텍스트의 형태
#     --> '실수화' 시켜줘야 함
# 2. `<h3>`도 태그 class로 `blind`를 가지고 있기 때문에, 등락의 값이 국가명으로 나옴
#     --> change의 옆이라는 것을 활용해 `nextSibling` 사용해보자

# %%
for fin in fin_list:
    # print("국가명 : {}".format(fin.find("h3", {"class":"h_lst"}).text))

    c_name = fin.find("h3", {"class":"h_lst"}).text
    # exchangeRate = soup.select("#exchangeList > li.on > a.head.usd > div > span.value")
    exchangeRate = fin.select_one("span.value").text
    change = fin.select_one("span.change").text
    updown = fin.select_one("span.change").nextSibling.nextSibling.text

    print("국가명 : {}".format(c_name))
    print("환율 : {}".format(float(exchangeRate.replace(",", ""))))
    print("변동 : {}".format(float(change))) 
    # change는 숫자의 모양을 하고 있는 문자열이기 때문에, 실수로 바꿔줘야 함
    print("등락 : {}".format(updown))

    print()
# Out:
# 국가명 : 미국 USD
# 환율 : 1147.5
# 변동 : 1.0
# 등락 : 하락
#
# 국가명 : 일본 JPY(100엔)
# 환율 : 1041.24
# 변동 : 2.8
# 등락 : 하락
#
# 국가명 : 유럽연합 EUR
# 환율 : 1360.88
# 변동 : 1.07
# 등락 : 하락
#
# 국가명 : 중국 CNY
# 환율 : 177.11
# 변동 : 0.17
# 등락 : 상승

# %% [markdown]
# # 무신사 스크레이핑

# %%
from urllib.request import urlopen, urlretrieve

url = "https://search.musinsa.com/category/001001"

# %%
data = urlopen(url)
data_html = data.read()
soup = BeautifulSoup(data_html)
soup

# %%
searchList = soup.select_one("#searchList") # searchList라는 id로 ul을 선택
print(searchList)
# Out:
# <ul class="snap-article-list boxed-article-list article-list center list goods_small_media8" id="searchList">
# <li class="li_box" data-no="1420730">
# <div class="icon_new">SALE 50%</div>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1420730" name="goods_link" title="[패키지] NYC LOCATION T-SHIRT (16 Colors) [LRPMCTA401M]">
# <img alt="[패키지] NYC LOCATION T-SHIRT (16 Colors) [LRPMCTA401M]" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20200424/1420730/1420730_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/grooverhyme/goods">그루브라임</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1420730" name="goods_link" title="[패키지] NYC LOCATION T-SHIRT (16 Colors) [LRPMCTA401M]">
#
#
#
#                                     [패키지] NYC LOCATION T-SHIRT (16 Colors) [LRPMCTA401M]
#                                 </a>
# </p>
# <p class="price">
# <del>58,000원</del> 29,000원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1420730', '1420730', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1420730" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1420730', '1420730', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">29,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:94%"></span>
# </span>
# <span class="count">23,522</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1420730" onclick="viewOption3(this, '1420730', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1420730" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1848166">
# <div class="icon_new">SALE 20%</div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1848166" name="goods_link" title="쿨 코튼 2-PACK 티셔츠">
# <img alt="쿨 코튼 2-PACK 티셔츠" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210316/1848166/1848166_4_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/covernat/goods">커버낫</a></p>
# <span class="icon_img_gift"><img alt="gift" src="//image.msscdn.net/skin/musinsa/images/ico_gift.gif"/></span>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1848166" name="goods_link" title="쿨 코튼 2-PACK 티셔츠">
# <strong class="txt_reserve">7/23 배송 </strong>
#
#                                     쿨 코튼 2-PACK 티셔츠
#                                 </a>
# </p>
# <p class="price">
# <del>43,000원</del> 34,400원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1848166', '1848166', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1848166" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1848166', '1848166', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">34,400원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:96%"></span>
# </span>
# <span class="count">10,271</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1848166" onclick="viewOption3(this, '1848166', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1848166" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="996177">
# <div class="box-icon-right">
# <span class="icon-box-musinsa icon-reverse">무신사 단독</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/996177" name="goods_link" title="릴렉스 핏 크루 넥 반팔 티셔츠 [화이트]">
# <img alt="릴렉스 핏 크루 넥 반팔 티셔츠 [화이트]" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20190327/996177/996177_3_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/musinsastandard/goods">무신사 스탠다드</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/996177" name="goods_link" title="릴렉스 핏 크루 넥 반팔 티셔츠 [화이트]">
#
#
#
#                                     릴렉스 핏 크루 넥 반팔 티셔츠 [화이트]
#                                 </a>
# </p>
# <p class="price">
#                                  11,900원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_996177', '996177', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_996177" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_996177', '996177', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">11,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:94%"></span>
# </span>
# <span class="count">45,650</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol996177" onclick="viewOption3(this, '996177', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol996177" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="903340">
# <div class="icon_new">SALE 30%</div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/903340" name="goods_link" title="빅 트위치 로고 티셔츠 화이트">
# <img alt="빅 트위치 로고 티셔츠 화이트" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20181112/903340/903340_7_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/lee/goods">리</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/903340" name="goods_link" title="빅 트위치 로고 티셔츠 화이트">
#
#
#
#                                     빅 트위치 로고 티셔츠 화이트
#                                 </a>
# </p>
# <p class="price">
# <del>35,000원</del> 24,500원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_903340', '903340', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_903340" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_903340', '903340', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">24,500원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:95%"></span>
# </span>
# <span class="count">9,571</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol903340" onclick="viewOption3(this, '903340', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol903340" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="996178">
# <div class="box-icon-right">
# <span class="icon-box-musinsa icon-reverse">무신사 단독</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/996178" name="goods_link" title="릴렉스 핏 크루 넥 반팔 티셔츠 [블랙]">
# <img alt="릴렉스 핏 크루 넥 반팔 티셔츠 [블랙]" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20190327/996178/996178_3_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/musinsastandard/goods">무신사 스탠다드</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/996178" name="goods_link" title="릴렉스 핏 크루 넥 반팔 티셔츠 [블랙]">
#
#
#
#                                     릴렉스 핏 크루 넥 반팔 티셔츠 [블랙]
#                                 </a>
# </p>
# <p class="price">
#                                  11,900원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_996178', '996178', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_996178" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_996178', '996178', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">11,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:95%"></span>
# </span>
# <span class="count">29,907</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol996178" onclick="viewOption3(this, '996178', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol996178" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1886950">
# <div class="icon_new">SALE 30%</div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1886950" name="goods_link" title="EMBROIDERY HANDSOME DAN TEE WHITE">
# <img alt="EMBROIDERY HANDSOME DAN TEE WHITE" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210407/1886950/1886950_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/yale/goods">예일</a></p>
# <span class="icon_img_gift"><img alt="gift" src="//image.msscdn.net/skin/musinsa/images/ico_gift.gif"/></span>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1886950" name="goods_link" title="EMBROIDERY HANDSOME DAN TEE WHITE">
#
#
#
#                                     EMBROIDERY HANDSOME DAN TEE WHITE
#                                 </a>
# </p>
# <p class="price">
# <del>39,000원</del> 27,300원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1886950', '1886950', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1886950" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1886950', '1886950', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">27,300원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:97%"></span>
# </span>
# <span class="count">2,656</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1886950" onclick="viewOption3(this, '1886950', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1886950" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1884943">
# <div class="icon_new">SALE 34%</div>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1884943" name="goods_link" title="미시간 울버린 피그먼트  반팔티 블랙차콜">
# <img alt="미시간 울버린 피그먼트  반팔티 블랙차콜" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210407/1884943/1884943_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/travel/goods">트래블</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1884943" name="goods_link" title="미시간 울버린 피그먼트  반팔티 블랙차콜">
#
#
#
#                                     미시간 울버린 피그먼트  반팔티 블랙차콜
#                                 </a>
# </p>
# <p class="price">
# <del>39,000원</del> 25,900원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1884943', '1884943', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1884943" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1884943', '1884943', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">25,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:95%"></span>
# </span>
# <span class="count">3,063</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1884943" onclick="viewOption3(this, '1884943', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1884943" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1900133">
# <div class="icon_new">SALE 10%</div>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1900133" name="goods_link" title="TAG RB TEE - BLACK">
# <img alt="TAG RB TEE - BLACK" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210415/1900133/1900133_2_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/brownbreath/goods">브라운브레스</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1900133" name="goods_link" title="TAG RB TEE - BLACK">
#
#
#
#                                     TAG RB TEE - BLACK
#                                 </a>
# </p>
# <p class="price">
# <del>32,000원</del> 28,800원
#                             </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-1,440원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1900133', '1900133', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1900133" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1900133', '1900133', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">28,800원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:96%"></span>
# </span>
# <span class="count">1,290</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1900133" onclick="viewOption3(this, '1900133', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1900133" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1876384">
# <div class="icon_new">SALE 20%</div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1876384" name="goods_link" title="쿠퍼 로고 티셔츠 네이비">
# <img alt="쿠퍼 로고 티셔츠 네이비" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210401/1876384/1876384_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/covernat/goods">커버낫</a></p>
# <span class="icon_img_gift"><img alt="gift" src="//image.msscdn.net/skin/musinsa/images/ico_gift.gif"/></span>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1876384" name="goods_link" title="쿠퍼 로고 티셔츠 네이비">
#
#
#
#                                     쿠퍼 로고 티셔츠 네이비
#                                 </a>
# </p>
# <p class="price">
# <del>39,000원</del> 31,200원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1876384', '1876384', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1876384" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1876384', '1876384', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">31,200원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:97%"></span>
# </span>
# <span class="count">1,738</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1876384" onclick="viewOption3(this, '1876384', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1876384" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1845608">
# <div class="icon_new">SALE 30%</div>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1845608" name="goods_link" title="슈무 아치로고 반팔 티셔츠 화이트">
# <img alt="슈무 아치로고 반팔 티셔츠 화이트" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210315/1845608/1845608_3_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/markgonzales/goods">마크 곤잘레스</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1845608" name="goods_link" title="슈무 아치로고 반팔 티셔츠 화이트">
#
#
#
#                                     슈무 아치로고 반팔 티셔츠 화이트
#                                 </a>
# </p>
# <p class="price">
# <del>39,000원</del> 27,300원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1845608', '1845608', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1845608" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1845608', '1845608', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">27,300원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:96%"></span>
# </span>
# <span class="count">1,820</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1845608" onclick="viewOption3(this, '1845608', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1845608" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1793420">
# <div class="icon_new">SALE 30%</div>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1793420" name="goods_link" title="빅 트위치 로고 티셔츠 블랙">
# <img alt="빅 트위치 로고 티셔츠 블랙" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210215/1793420/1793420_5_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/lee/goods">리</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1793420" name="goods_link" title="빅 트위치 로고 티셔츠 블랙">
#
#
#
#                                     빅 트위치 로고 티셔츠 블랙
#                                 </a>
# </p>
# <p class="price">
# <del>35,000원</del> 24,500원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1793420', '1793420', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1793420" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1793420', '1793420', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">24,500원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:96%"></span>
# </span>
# <span class="count">1,774</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1793420" onclick="viewOption3(this, '1793420', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1793420" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="987149">
# <div class="icon_new">SALE 17%</div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/987149" name="goods_link" title="[패키지] 에디 오버핏 반팔티셔츠 패키지 KJST2189">
# <img alt="[패키지] 에디 오버핏 반팔티셔츠 패키지 KJST2189" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20190319/987149/987149_3_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/jemut/goods">제멋</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/987149" name="goods_link" title="[패키지] 에디 오버핏 반팔티셔츠 패키지 KJST2189">
#
#
#
#                                     [패키지] 에디 오버핏 반팔티셔츠 패키지 KJST2189
#                                 </a>
# </p>
# <p class="price">
# <del>35,800원</del> 29,800원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_987149', '987149', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_987149" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_987149', '987149', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">29,800원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:93%"></span>
# </span>
# <span class="count">10,984</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol987149" onclick="viewOption3(this, '987149', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol987149" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1425234">
# <div class="icon_new">SALE 17%</div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1425234" name="goods_link" title="[패키지]아이스버그 반팔 STST3279 + 스플래쉬 반팔 STST3278">
# <img alt="[패키지]아이스버그 반팔 STST3279 + 스플래쉬 반팔 STST3278" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20200428/1425234/1425234_2_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/twn/goods">티떠블유엔</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1425234" name="goods_link" title="[패키지]아이스버그 반팔 STST3279 + 스플래쉬 반팔 STST3278">
#
#
#
#                                     [패키지]아이스버그 반팔 STST3279 + 스플래쉬 반팔 STST3278
#                                 </a>
# </p>
# <p class="price">
# <del>47,800원</del> 39,800원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1425234', '1425234', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1425234" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1425234', '1425234', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">39,800원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:94%"></span>
# </span>
# <span class="count">6,428</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1425234" onclick="viewOption3(this, '1425234', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1425234" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1827193">
# <div class="icon_new">SALE 30%</div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1827193" name="goods_link" title="UNIVERSITY HANDSOME DAN TEE WHITE">
# <img alt="UNIVERSITY HANDSOME DAN TEE WHITE" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210304/1827193/1827193_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/yale/goods">예일</a></p>
# <span class="icon_img_gift"><img alt="gift" src="//image.msscdn.net/skin/musinsa/images/ico_gift.gif"/></span>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1827193" name="goods_link" title="UNIVERSITY HANDSOME DAN TEE WHITE">
#
#
#
#                                     UNIVERSITY HANDSOME DAN TEE WHITE
#                                 </a>
# </p>
# <p class="price">
# <del>42,000원</del> 29,400원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1827193', '1827193', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1827193" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1827193', '1827193', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">29,400원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:96%"></span>
# </span>
# <span class="count">2,246</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1827193" onclick="viewOption3(this, '1827193', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1827193" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1403092">
# <div class="icon_new">SALE 30%</div>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1403092" name="goods_link" title="스트라이프 반팔 티셔츠 블랙">
# <img alt="스트라이프 반팔 티셔츠 블랙" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20200414/1403092/1403092_5_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/markgonzales/goods">마크 곤잘레스</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1403092" name="goods_link" title="스트라이프 반팔 티셔츠 블랙">
#
#
#
#                                     스트라이프 반팔 티셔츠 블랙
#                                 </a>
# </p>
# <p class="price">
# <del>39,000원</del> 27,300원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1403092', '1403092', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1403092" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1403092', '1403092', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">27,300원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:95%"></span>
# </span>
# <span class="count">6,022</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1403092" onclick="viewOption3(this, '1403092', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1403092" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1845485">
# <div class="icon_new">SALE 30%</div>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1845485" name="goods_link" title="더블엔젤 와펜 반팔 티셔츠 블랙">
# <img alt="더블엔젤 와펜 반팔 티셔츠 블랙" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210315/1845485/1845485_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/markgonzales/goods">마크 곤잘레스</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1845485" name="goods_link" title="더블엔젤 와펜 반팔 티셔츠 블랙">
#
#
#
#                                     더블엔젤 와펜 반팔 티셔츠 블랙
#                                 </a>
# </p>
# <p class="price">
# <del>39,000원</del> 27,300원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1845485', '1845485', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1845485" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1845485', '1845485', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">27,300원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:96%"></span>
# </span>
# <span class="count">1,605</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1845485" onclick="viewOption3(this, '1845485', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1845485" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1886956">
# <div class="icon_new">SALE 30%</div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1886956" name="goods_link" title="EMBROIDERY HANDSOME DAN TEE BLACK">
# <img alt="EMBROIDERY HANDSOME DAN TEE BLACK" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210407/1886956/1886956_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/yale/goods">예일</a></p>
# <span class="icon_img_gift"><img alt="gift" src="//image.msscdn.net/skin/musinsa/images/ico_gift.gif"/></span>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1886956" name="goods_link" title="EMBROIDERY HANDSOME DAN TEE BLACK">
#
#
#
#                                     EMBROIDERY HANDSOME DAN TEE BLACK
#                                 </a>
# </p>
# <p class="price">
# <del>39,000원</del> 27,300원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1886956', '1886956', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1886956" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1886956', '1886956', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">27,300원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:97%"></span>
# </span>
# <span class="count">987</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1886956" onclick="viewOption3(this, '1886956', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1886956" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1830175">
# <div class="icon_new">SALE 30%</div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1830175" name="goods_link" title="LMC WATER SPLASH TEE white">
# <img alt="LMC WATER SPLASH TEE white" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210305/1830175/1830175_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/lmc/goods">엘엠씨</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1830175" name="goods_link" title="LMC WATER SPLASH TEE white">
#
#
#
#                                     LMC WATER SPLASH TEE white
#                                 </a>
# </p>
# <p class="price">
# <del>39,000원</del> 27,300원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1830175', '1830175', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1830175" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1830175', '1830175', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">27,300원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:96%"></span>
# </span>
# <span class="count">1,871</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1830175" onclick="viewOption3(this, '1830175', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1830175" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="996497">
# <div class="box-icon-right">
# <span class="icon-box-musinsa icon-reverse">무신사 단독</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/996497" name="goods_link" title="베이식 크루 넥 반팔 티셔츠 [화이트]">
# <img alt="베이식 크루 넥 반팔 티셔츠 [화이트]" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20190327/996497/996497_4_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/musinsastandard/goods">무신사 스탠다드</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/996497" name="goods_link" title="베이식 크루 넥 반팔 티셔츠 [화이트]">
#
#
#
#                                     베이식 크루 넥 반팔 티셔츠 [화이트]
#                                 </a>
# </p>
# <p class="price">
#                                  10,900원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_996497', '996497', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_996497" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_996497', '996497', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">10,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:94%"></span>
# </span>
# <span class="count">13,320</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol996497" onclick="viewOption3(this, '996497', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol996497" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1860490">
# <div class="icon_new">SALE 61%</div>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1860490" name="goods_link" title="[패키지] 10TH ANNIVERSARY 3PACK T-SHIRTS EDITION">
# <img alt="[패키지] 10TH ANNIVERSARY 3PACK T-SHIRTS EDITION" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210324/1860490/1860490_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/grooverhyme/goods">그루브라임</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1860490" name="goods_link" title="[패키지] 10TH ANNIVERSARY 3PACK T-SHIRTS EDITION">
#
#
#
#                                     [패키지] 10TH ANNIVERSARY 3PACK T-SHIRTS EDITION
#                                 </a>
# </p>
# <p class="price">
# <del>75,000원</del> 29,000원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1860490', '1860490', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1860490" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1860490', '1860490', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">29,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:95%"></span>
# </span>
# <span class="count">1,185</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1860490" onclick="viewOption3(this, '1860490', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1860490" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1356896">
# <div class="icon_new">SALE 20%</div>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1356896" name="goods_link" title="M-Logo Classic (GL5TSU173WH)">
# <img alt="M-Logo Classic (GL5TSU173WH)" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20200318/1356896/1356896_2_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/jeep/goods">지프</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1356896" name="goods_link" title="M-Logo Classic (GL5TSU173WH)">
#
#
#
#                                     M-Logo Classic (GL5TSU173WH)
#                                 </a>
# </p>
# <p class="price">
# <del>35,000원</del> 28,000원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1356896', '1356896', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1356896" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1356896', '1356896', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">28,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:92%"></span>
# </span>
# <span class="count">3,683</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1356896" onclick="viewOption3(this, '1356896', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1356896" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1005683">
# <div class="icon_new">SALE 30%</div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1005683" name="goods_link" title="사인로고 반팔 티셔츠 블랙">
# ...
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:97%"></span>
# </span>
# <span class="count">736</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1838095" onclick="viewOption3(this, '1838095', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1838095" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1825927">
# <div class="icon_new">SALE 30%</div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1825927" name="goods_link" title="Overdyed Mars Tee Charcoal">
# <img alt="Overdyed Mars Tee Charcoal" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210304/1825927/1825927_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/thisisneverthat/goods">디스이즈네버댓</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1825927" name="goods_link" title="Overdyed Mars Tee Charcoal">
#
#
#
#                                     Overdyed Mars Tee Charcoal
#                                 </a>
# </p>
# <p class="price">
# <del>49,000원</del> 34,300원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1825927', '1825927', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1825927" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1825927', '1825927', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">34,300원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:97%"></span>
# </span>
# <span class="count">873</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1825927" onclick="viewOption3(this, '1825927', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1825927" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1860815">
# <div class="icon_new">SALE 20%</div>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1860815" name="goods_link" title="엔젤 와펜 반팔 티셔츠 화이트">
# <img alt="엔젤 와펜 반팔 티셔츠 화이트" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210324/1860815/1860815_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/markgonzales/goods">마크 곤잘레스</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1860815" name="goods_link" title="엔젤 와펜 반팔 티셔츠 화이트">
#
#
#
#                                     엔젤 와펜 반팔 티셔츠 화이트
#                                 </a>
# </p>
# <p class="price">
# <del>39,000원</del> 31,200원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1860815', '1860815', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1860815" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1860815', '1860815', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">31,200원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:97%"></span>
# </span>
# <span class="count">1,172</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1860815" onclick="viewOption3(this, '1860815', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1860815" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1820696">
# <div class="icon_new">SALE 30%</div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1820696" name="goods_link" title="빅 트위치 로고 티셔츠 퍼플">
# <img alt="빅 트위치 로고 티셔츠 퍼플" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210302/1820696/1820696_3_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/lee/goods">리</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1820696" name="goods_link" title="빅 트위치 로고 티셔츠 퍼플">
# <strong class="txt_reserve">7/13 배송 </strong>
#
#                                     빅 트위치 로고 티셔츠 퍼플
#                                 </a>
# </p>
# <p class="price">
# <del>35,000원</del> 24,500원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1820696', '1820696', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1820696" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1820696', '1820696', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">24,500원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:96%"></span>
# </span>
# <span class="count">489</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1820696" onclick="viewOption3(this, '1820696', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1820696" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="1841764">
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1841764" name="goods_link" title="2 TONE ARCH TEE WHITE">
# <img alt="2 TONE ARCH TEE WHITE" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210312/1841764/1841764_2_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/yale/goods">예일</a></p>
# <span class="icon_img_gift"><img alt="gift" src="//image.msscdn.net/skin/musinsa/images/ico_gift.gif"/></span>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1841764" name="goods_link" title="2 TONE ARCH TEE WHITE">
#
#
#
#                                     2 TONE ARCH TEE WHITE
#                                 </a>
# </p>
# <p class="price">
#                                  39,000원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1841764', '1841764', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1841764" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1841764', '1841764', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">39,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:97%"></span>
# </span>
# <span class="count">657</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1841764" onclick="viewOption3(this, '1841764', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1841764" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="501693">
# <div class="box-icon-right">
# <p class="delivery_text"><span class="icon-box-income">병행수입</span></p>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/501693" name="goods_link" title="포켓 반팔티 17종 / K87">
# <img alt="포켓 반팔티 17종 / K87" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20170317/501693/501693_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/carhartt/goods">칼하트</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/501693" name="goods_link" title="포켓 반팔티 17종 / K87">
#
#
#
#                                     포켓 반팔티 17종 / K87
#                                 </a>
# </p>
# <p class="price">
#                                  59,000원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_501693', '501693', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_501693" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_501693', '501693', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">59,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:93%"></span>
# </span>
# <span class="count">8,114</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol501693" onclick="viewOption3(this, '501693', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol501693" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="726408">
# <div class="icon_new">SALE 30%</div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/726408" name="goods_link" title="[Mmlg] MMLG HF-T (WHITE)">
# <img alt="[Mmlg] MMLG HF-T (WHITE)" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20180228/726408/726408_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/mmlg/goods">엠엠엘지</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/726408" name="goods_link" title="[Mmlg] MMLG HF-T (WHITE)">
#
#
#
#                                     [Mmlg] MMLG HF-T (WHITE)
#                                 </a>
# </p>
# <p class="price">
# <del>39,000원</del> 27,300원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_726408', '726408', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_726408" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_726408', '726408', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">27,300원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:94%"></span>
# </span>
# <span class="count">3,984</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol726408" onclick="viewOption3(this, '726408', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol726408" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-no="996179">
# <div class="box-icon-right">
# <span class="icon-box-musinsa icon-reverse">무신사 단독</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/996179" name="goods_link" title="릴렉스 핏 크루 넥 반팔 티셔츠 [다크 그레이]">
# <img alt="릴렉스 핏 크루 넥 반팔 티셔츠 [다크 그레이]" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20190327/996179/996179_3_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/musinsastandard/goods">무신사 스탠다드</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/996179" name="goods_link" title="릴렉스 핏 크루 넥 반팔 티셔츠 [다크 그레이]">
#
#
#
#                                     릴렉스 핏 크루 넥 반팔 티셔츠 [다크 그레이]
#                                 </a>
# </p>
# <p class="price">
#                                  11,900원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_996179', '996179', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_996179" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_996179', '996179', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">11,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:95%"></span>
# </span>
# <span class="count">4,383</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol996179" onclick="viewOption3(this, '996179', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol996179" style="display:none;"></div>
# </div>
# </li>
# </ul>

# %%
products = soup.select("#searchList > li")
len(products)
# Out:
# 90

# %%
products[0]
# Out:
# <li class="li_box" data-no="1420730">
# <div class="icon_new">SALE 50%</div>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1420730" name="goods_link" title="[패키지] NYC LOCATION T-SHIRT (16 Colors) [LRPMCTA401M]">
# <img alt="[패키지] NYC LOCATION T-SHIRT (16 Colors) [LRPMCTA401M]" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20200424/1420730/1420730_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://display.musinsa.com/display/brands/grooverhyme/goods">그루브라임</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1420730" name="goods_link" title="[패키지] NYC LOCATION T-SHIRT (16 Colors) [LRPMCTA401M]">
#
#
#
#                                     [패키지] NYC LOCATION T-SHIRT (16 Colors) [LRPMCTA401M]
#                                 </a>
# </p>
# <p class="price">
# <del>58,000원</del> 29,000원
#                             </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1420730', '1420730', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1420730" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="#" onclick="viewMemberPrice2('sPrice_1420730', '1420730', '0');return false;">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
#                                         비회원<span class="txt_price_member">29,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width:94%"></span>
# </span>
# <span class="count">23,522</span>
# </p>
# <p class="txt_cnt_like" style="display: none">
# <img alt="좋아요" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1420730" onclick="viewOption3(this, '1420730', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1420730" style="display:none;"></div>
# </div>
# </li>

# %%
products[0].select_one("img.lazyload")['data-original']

# %%
# 불러온 이미지를 파일로 저장
urlretrieve(products[0].select_one("img.lazyload")['data-original'], 'sample.jpg')

# %%
# 이미지 저장_ver2
img_url = products[0].select_one("img.lazyload")['data-original']
urlretrieve(img_url, img_url.split("/")[-1])

# %%
# 브랜드
item_title = products[0].select_one("p.item_title").text
print(item_title)

# %%
# 상품명
product_name = products[0].select_one("p.list_info").text.strip()
print(product_name)

# %%
# 가격
product_price = products[0].select_one("p.price").find("del").nextSibling.strip()
print(float(product_price.replace(",", "").replace("원","")))

# %%
# 별점 등록 수
star_count = products[0].select_one("p.point > span.count").text
print(int(star_count.replace(",", "")))

# %%
# # 좋아요 수
# like_count = products[0].select_one("p.txt_cnt_like")
# print(like_count)

# %%
product_idx = []
product_img_url_list = []
product_brand_list = []
product_name_list = []
product_price_list = []
product_star_count_list = []

for product in products:
  img_url = product.select_one("img.lazyload")['data-original']
  urlretrieve(img_url, img_url.split("/")[-1])

  # 브랜드
  product_title = product.select_one("p.item_title").text
  
  # 상품명
  product_name = product.select_one("p.list_info").text.strip()

  # 가격
  price_del_elem = product.select_one("p.price").find("del")

  # <del> 태그가 있으면..
  if price_del_elem:
    product_price = price_del_elem.nextSibling.strip()
  else: # <del> 태그가 없으면..
    product_price = product.select_one("p.price").text.strip()

  # 별점 등록 수
  star_count = product.select_one("p.point > span.count").text.replace(",", "")
  
  # 상품 id
  product_id = product['data-no']

  product_idx.append(product_id)
  product_img_url_list.append(img_url)
  product_brand_list.append(product_title)
  product_name_list.append(product_name)
  product_price_list.append(product_price)
  product_star_count_list.append(star_count)

# %%
import pandas as pd
datas = {
    "상품ID" : product_idx,
    "상품이미지URL": product_img_url_list,
    "상품브랜드": product_brand_list,
    "상품명": product_name_list,
    "상품가격": product_price_list,
    "상품별점등록수": product_star_count_list
}

df = pd.DataFrame(datas)
df.head()
